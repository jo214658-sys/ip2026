# %%
import numpy as np
import cv2

# %%
img = cv2.imread("mountain.jpg.png")

# %%
px = img[100,100]
print px

blue = img[100,100,0]
print blue
# Out:
#   Cell In[6], line 2
#     print px
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(px)?

# %%
img[100,100]=[255,255,255]
print img[100,100,0]
# Out:
#   Cell In[7], line 2
#     print img[100,100,0]
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(img[100,100,0])?

# %%
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img[200:400, 200:400, 2] = 255

# %%
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
