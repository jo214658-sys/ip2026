# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread('mountain.jpg')
img2 = cv2.imread('opencv_logo.jpg')
# I want to put logo on top-left corner, So I create a ROI
rows,cols,channels = img2.shape
roi = img1[0:rows, 0:cols ]
# Now create a mask of logo and create its inverse mask also
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)

ret, mask = cv2.threshold(img2gray, 25, 225, cv2.THRESH_BINARY)

plt.subplot(131), plt.imshow(img2)
plt.subplot(132), cv2.imshow(img2gray, 'gray')
plt.subplot(133), cv2.imshow(mask,'gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[20], line 12
#       9 ret, mask = cv2.threshold(img2gray, 25, 225, cv2.THRESH_BINARY)
#      11 plt.subplot(131), plt.imshow(img2)
# ---> 12 plt.subplot(132), cv2.imshow(img2gray, 'gray')
#      13 plt.subplot(133), cv2.imshow(mask,'gray')
#      14 plt.show()
#
# error: OpenCV(4.13.0) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - Can't convert object to 'str' for 'winname'
# >  - Can't convert object to 'str' for 'winname'
# >  - Can't convert object to 'str' for 'winname'
